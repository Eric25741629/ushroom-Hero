# %%
import cv2
import numpy as np
img = cv2.imread(r'A:\main4_1746057661.705409.jpg')
import matplotlib.pyplot as plt

# 讀取圖片

# 棋盤區域設定（左上角和右下角座標）
top_left = (6, 227)
bottom_right = (535, 852)

# 棋盤尺寸：6列 × 7行（columns × rows）
cols, rows = 6, 7

# 計算格子大小
cell_width = int(round(bottom_right[0] - top_left[0]) / cols)
cell_height = int(round(bottom_right[1] - top_left[1]) / rows)

# 畫出橫線與直線
for i in range(rows + 1):
    y = int(top_left[1] + i * cell_height)
    print(f"y: {y}")
    cv2.line(img, (top_left[0], y), (bottom_right[0], y), (0, 255, 0), 1)

for j in range(cols + 1):
    x = int(top_left[0] + j * cell_width)
    cv2.line(img, (x, top_left[1]), (x, bottom_right[1]), (0, 255, 0), 1)

# 顯示圖像（使用 Matplotlib 因為 OpenCV imshow 不適用於非本地環境）
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8, 10))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("6x7 Chessboard Overlay")
plt.show()
# Out:
# y: 227
# y: 316
# y: 405
# y: 494
# y: 583
# y: 672
# y: 761
# y: 850

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import uiautomator2 as u2
import time
# 讀取圖片
d = u2.connect('emulator-5562')
# img = d.screenshot(format='opencv')
# cv2.imshow('screenshot', img)
# cv2.waitKey(0)
xlist=[41,176,222,312,401,487]
test=0
while True:
    img = d.screenshot(format='opencv')
    # 棋盤左上與右下角位置
    top_left = (6, 227)
    bottom_right = (535, 852)

    # 棋盤設定：6 列 × 7 行（cols × rows）
    cols, rows = 6, 7

    # 計算每格大小（四捨五入並強制整數）
    cell_width = int(round((bottom_right[0] - top_left[0]) / cols))
    cell_height = int(round((bottom_right[1] - top_left[1]) / rows))

    # 建立輸出資料夾
    output_dir = "extracted_cells"
    os.makedirs(output_dir, exist_ok=True)

    # 逐格裁切並儲存
    for row in range(rows):
        for col in range(cols):
            x1 = top_left[0] + col * cell_width
            y1 = top_left[1] + row * cell_height
            x2 = x1 + cell_width
            y2 = y1 + cell_height

            cell = img[y1:y2, x1:x2]
            filename = f"{output_dir}/cell_r{row}_c{col}{time.time()}.png"
            cv2.imwrite(filename, cell)

    print(f"✅ All {rows * cols} cells saved to '{output_dir}'")
    d.click(312,798)
    time.sleep(3)
# Out:
# ✅ All 42 cells saved to 'extracted_cells'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[128], line 45
#      43 print(f"✅ All {rows * cols} cells saved to '{output_dir}'")
#      44 d.click(312,798)
# ---> 45 time.sleep(3)
#
# KeyboardInterrupt:

# %%
import heapq, copy
# ----------------- 基本設定 -----------------
H, W = 7, 6
TREASURE_BASE = {'gold', 'silver', 'copper', 'skill', 'partner'}
TREASURES = TREASURE_BASE | {f'dis_{t}' for t in TREASURE_BASE}

HARDNESS = {'dirt': 1, 'rock': 2, 'one-step-rock': 1,
            'copper': 1, 'silver': 1, 'gold': 1,
            'skill': 1, 'partner': 1}
SCORE = {'copper': 300, 'silver': 800, 'gold': 1500, 'skill': 500, 'partner': 500}

def in_bounds(y, x): return 0 <= y < H and 0 <= x < W
DIR4 = [(-1, 0), (1, 0), (0, -1), (0, 1)]
def cost_of(cell):  return HARDNESS.get(cell, 1)
def score_of(cell): return SCORE.get(cell, 0)
UNLOCK_BONUS = 200      # 打通「斷線寶物」給的額外分數
def unlock_gain(grid, x, y, already_unlocked):
    """若在 (x,y) 變成 'e'，可一次性解鎖多少 dis_*？"""
    gain = 0
    newly = set()
    for dy, dx in DIR4:
        nx, ny = x+dx, y+dy
        if not in_bounds(ny, nx):
            continue
        cell = grid[ny][nx]
        if cell.startswith('dis_') and (nx, ny) not in already_unlocked:
            base = cell[4:]                     # 'dis_copper' → 'copper'
            gain += UNLOCK_BONUS + SCORE.get(base, 0)
            newly.add((nx, ny))
    return gain, newly

# -------------------------------------------------
def find_multi_paths(grid, beam_k=10, max_len=5):
    """
    回傳 (best_path, best_net_value)
    best_path  : [(x,y)...] 依序要挖的座標
    best_value : 總工具成本 - 總寶物得分   （越小越好）
    """
    best_path   = None
    best_value  = float('inf')

    # ---------- 初始節點：所有與 'e' 相鄰、需挖掘的方塊 ----------
    open_q = []
    for y in range(H):
        for x in range(W):
            if grid[y][x] == 'e':
                continue
            if not any(in_bounds(y+dy, x+dx) and grid[y+dy][x+dx] == 'e'
                       for dy, dx in DIR4):
                continue   # 不鄰接空格，不能作為第一鎚
            cost  = cost_of(grid[y][x])
            score = score_of(grid[y][x])
            treasures = {(x, y)} if grid[y][x] in TREASURES else set()
            net   = cost - score
            state = (net, cost, score, (x, y), treasures, [(x, y)])
            heapq.heappush(open_q, state)

    # ---------- Beam / Best-First 展開 ----------
    for _ in range(max_len - 1):          # 已經花 1 步；還能再展開 max_len-1 步
        new_q = []
        while open_q:
            net, cost, score, (cx, cy), ts, path = heapq.heappop(open_q)

            # 先更新目前最佳
            if net < best_value:
                best_value, best_path = net, path

        # ---------- 向四鄰擴張 ----------
        for dy, dx in DIR4:
            nx, ny = cx + dx, cy + dy
            if not in_bounds(ny, nx):
                continue
            if (nx, ny) in path or grid[ny][nx] == 'e':
                continue       # 已走過或本來就是空洞

            cell = grid[ny][nx]

            # --- 成本與基本得分 ---
            cost_inc  = cost_of(cell)
            score_inc = score_of(cell) if cell in TREASURES and (nx, ny) not in ts else 0

            # --- ⬇️  【重點】計算打通後的解鎖收益 ------------
            unlock_inc, newly = unlock_gain(grid, nx, ny, ts)

            new_cost  = cost + cost_inc
            new_score = score + score_inc + unlock_inc
            new_ts    = ts | newly
            if score_inc > 0:
                new_ts.add((nx, ny))     # 把自己也標成已拿

            new_net  = new_cost - new_score
            new_path = path + [(nx, ny)]
            new_state = (new_net, new_cost, new_score, (nx, ny), new_ts, new_path)
            heapq.heappush(new_q, new_state)

        # Beam 裁剪：只保留淨效用最小的前 beam_k 條
        open_q = heapq.nsmallest(beam_k, new_q)
        if not open_q: break

    # 最後再更新一次（避免 max_len = 1 的情況）
    for s in open_q:
        if s[0] < best_value:
            best_value, best_path = s[0], s[-1]

    return best_path, best_value
# -------------------------------------------------

# ---------- 示範棋盤（把 (4,6) 改成真正的 copper 看效果） ----------
board = [
    ['e','e','e','e','rock','e'],
    ['rock','rock','e','dirt','dis_e','dirt'],
    ['rock','e','e','rock','dis_dirt','dis_rock'],
    ['dis_dirt','dirt','e','dirt','dis_dirt','dis_dirt'],
    ['dirt','e','e','dirt','dis_dirt','dis_dirt'],
    ['dis_dirt','rock','e','rock','dis_rock','dis_dirt'],
    ['dis_dirt','dis_partner','rock','dis_dirt','dis_copper','dis_rock']  # ★ (4,6) → copper
]

best, val = find_multi_paths(board, beam_k=12, max_len=4)
if best:
    print(">> 推薦路徑 (總步數 ≤ 4)：")
    for i, (x, y) in enumerate(best, 1):
        print(f"  Step {i}: dig ({x},{y}) -> {board[y][x]}")
    print("淨效用 (工具成本 - 寶物得分):", val)
else:
    print(">> 在 4 步內找不到更好的挖礦策略")
# Out:
# >> 推薦路徑 (總步數 ≤ 4)：
#   Step 1: dig (4,0) -> rock
#   Step 2: dig (4,1) -> dis_e
#   Step 3: dig (4,2) -> dis_dirt
# 淨效用 (工具成本 - 寶物得分): -796

# %%
import cv2, copy, heapq
import torch, torch.nn.functional as F
from torchvision import transforms
import numpy as np
from PIL import Image
from itertools import count
from typing import List, Tuple
from simplecnn import SimpleCNN
class MiningPlanner:
    # ---- 常數（可依實際遊戲再調）----
    H, W = 7, 6                                 # 棋盤格數 y, x
    TREASURE_BASE = {'gold','silver','copper','skill','partner'}
    TREASURES = TREASURE_BASE | {f'dis_{t}' for t in TREASURE_BASE}
    HARDNESS = {'dirt':1,'rock':2,'one-step-rock':1,
                'copper':1,'silver':1,'gold':1,'skill':1,'partner':1}
    SCORE = {'copper':300,'silver':800,'gold':1500,'skill':500,'partner':500}
    UNLOCK_BONUS = 200
    DIR4 = [(-1,0),(1,0),(0,-1),(0,1)]
    uid = count()                  # for heap tie-break
    # ----------------- 估價函式 -----------------
    def cost_of(self,cell): return self.HARDNESS.get(cell,1)
    def score_of(self,cell): return self.SCORE.get(cell,0)

    # ---- 初始化 ----
    def __init__(self,
                 model: torch.nn.Module,
                 transform,
                 class_names: List[str],
                 board_lt: Tuple[int,int],        # 影像左上格 (x,y)
                 board_rb: Tuple[int,int],        # 影像右下格 (x,y)
                 device='cpu'):
        self.model = model.to(device)
        self.model.eval()
        self.tr = transform
        self.class_names = class_names
        self.lt = board_lt
        self.rb = board_rb
        self.device = device

        # 預算 / beam 參數可外調
        self.beam_k = 6
        self.max_len = 3

    # ---- 工具函式 ----
    @staticmethod
    def in_bounds(y,x): return 0<=y<MiningPlanner.H and 0<=x<MiningPlanner.W

    # -------- 1. 影像 → 7×6 類別矩陣 --------


    def find_paths(self,grid, beam_k=6, max_len=4):

        best_path = None
        best_value = float('inf')        # A*用「越小越好」

        # 搜尋所有寶物作為終點
        for y in range(self.H):
            for x in range(self.W):
                cell = grid[y][x]
                if cell not in self.TREASURES: continue
                target_score = self.score_of(cell)

                # open: (F, G, path), path = list[(x,y)]
                open_q = []
                # 從寶物出發：G=0 (已不需挖寶物本身)，H=曼哈頓距離估成本
                heapq.heappush(open_q, (0, 0, [(x,y)]))

                for depth in range(max_len):
                    new_q = []
                    while open_q:
                        F, G, path = heapq.heappop(open_q)
                        cx, cy = path[-1]
                        # 若已到相鄰 e，形成完整路徑
                        if any(self.in_bounds(cy+dy,cx+dx) and grid[cy+dy][cx+dx]=='e'
                            for dy,dx in self.DIR4):
                            if depth<=max_len-1:
                                total_cost = G          # 目前累積的工具成本
                                net = total_cost - target_score
                                if net < best_value:
                                    best_value = net
                                    best_path = list(reversed(path)) # 反向→自 e 到寶物
                            continue

                        # 延伸鄰接可挖方塊
                        for dy,dx in self.DIR4:
                            ny,nx = cy+dy, cx+dx
                            if not self.in_bounds(ny,nx):  continue
                            nxt = grid[ny][nx]
                            if nxt=='e' or nxt.startswith('dis_'): continue
                            if (nx,ny) in path: continue
                            g_cost = G + self.cost_of(nxt)
                            h_cost = 0  # 深度≤3，小圖可設0；或設估價距離
                            heapq.heappush(new_q, (g_cost+h_cost, g_cost, path+[(nx,ny)]))

                    # Beam 裁剪
                    open_q = heapq.nsmallest(beam_k, new_q)
                    if not open_q: break

        return best_path, best_value


    # -------- 4. 對外主函式 --------
    def plan(self, img_path:str):
        board=self.classify_board(img_path)
        path,val=self.find_paths(board,self.beam_k,self.max_len)
        return board,path,val

class_names = ["boom",
"copper",
"dirt",
"dis_boom",
"dis_coper",
"dis_dirt",
"dis_drill",
"dis_e",
"dis_gold",
"dis_partenr",
"dis_rock",
"dis_rube",
"dis_silver",
"dis_skill",
"drill",
"e",
"gold",
"one-step-rock",
"partner",
"rock",
"rube",
"silver",
"skill",]
# ======== 圖像前處理 ========
img_transform = transforms.Compose([
    transforms.Resize((64,64)),
    transforms.ToTensor(),
])
if __name__ == "__main__":
    top_left = (6, 227)
    bottom_right = (535, 852)
    simpleCNN = SimpleCNN(num_classes=len(class_names))
    # 假設你已經有 trained_model, img_transform, class_names
    trained_model = simpleCNN
    trained_model.load_state_dict(torch.load(r"A:\菇勇者全自動掛機\miner\oralce_model.pth"))
    trained_model.eval()
    planner = MiningPlanner(trained_model, img_transform, class_names,
                                board_lt=top_left, board_rb=bottom_right, device='cuda')
    board, moves, value = planner.plan("A:/main3_1746086766.9355874.jpg")
    print("分類矩陣:")
    for r in board: print(r)


    if moves:
        print("\n推薦行動序列:")
        for i,a in enumerate(moves,1):
            print(f"Step{i}: {a['type']}→{a['origin']}  cost={a['cost']} gain={a['score']}")
        print("淨效用:", value)
    else:
        print("無 3 步內路徑，建議挖底層捲動")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[144], line 8
#       6 from itertools import count
#       7 from typing import List, Tuple
# ----> 8 from simplecnn import SimpleCNN
#       9 class MiningPlanner:
#      10     # ---- 常數（可依實際遊戲再調）----
#      11     H, W = 7, 6                                 # 棋盤格數 y, x
#
# ModuleNotFoundError: No module named 'simplecnn'

# %%
# Out:
# C:\Users\eric\AppData\Local\Temp\ipykernel_77780\889513342.py:266: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trained_model.load_state_dict(torch.load(
# 分類矩陣:
# ['e', 'e', 'e', 'e', 'dirt', 'dis_e']
# ['dirt', 'rock', 'e', 'e', 'dirt', 'dis_rock']
# ['dirt', 'rock', 'e', 'dirt', 'dirt', 'dirt']
# ['e', 'e', 'e', 'e', 'e', 'e']
# ['e', 'e', 'e', 'e', 'dirt', 'e']
# ['dirt', 'e', 'rock', 'e', 'dirt', 'e']
# ['dis_dirt', 'rock', 'dis_dirt', 'dirt', 'dis_e', 'dirt']
# Dig at board (3,6) → image pixel (314,805)

# %%
import uiautomator2 as u2
import easyocr
import time


d=u2.connect('emulator-5554')
ocr = easyocr.Reader(['ch_tra','en'], gpu=True)

# %%
img = d.screenshot(format='opencv')[80:120,126:300]
results = ocr.readtext(img, detail=1)
num_before_slash = int(results[0][1].split('/')[0].rsplit(':', 1)[-1].strip())
print(num_before_slash)
# for (bbox, text, prob) in results:
#     print(f"文字: {text}, 機率: {prob:.2f}")
    # cv2.rectangle(img, (int(bbox[0][0]), int(bbox[0][1])), (int(bbox[2][0]), int(bbox[2][1])), (255, 0, 0), 2)
    # cv2.putText(img, text, (int(bbox[0][0]), int(bbox[0][1]) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
# Out:
# 2

# %%
#!/usr/bin/env python
# coding: utf-8
"""
train_miner.py  ‒  RL pipeline for the 6×7 mining game
======================================================

用法
----
$ python train_miner.py --teacher_file teacher_logs.jsonl \
                        --algo PPO \
                        --total_timesteps 200_000
"""
from __future__ import annotations
import argparse, json, random, itertools, os, sys
from pathlib import Path
from typing import List, Tuple, Dict
from stable_baselines3.common.policies import ActorCriticPolicy

import numpy as np
import gymnasium as gym
from gymnasium import spaces
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# ----------------------------------------------------------
# 0. 一些常數定義
# ----------------------------------------------------------
WIDTH, HEIGHT = 6, 7
LABELS = [                      # 23 + 1 ('unknown')
    "e","dirt","rock","one-step-rock",
    "copper","silver","gold","rube","skill","partner",
    "drill","boom","dis_boom","dis_drill",
    "dis_e","dis_dirt","dis_rock","dis_one-step-rock",
    "dis_copper","dis_silver","dis_gold","dis_rube",
    "dis_skill","dis_partner","unknown"
]
LBL2ID: Dict[str,int] = {lbl:i for i,lbl in enumerate(LABELS)}
ID2LBL: Dict[int,str] = {i:lbl for lbl,i in LBL2ID.items()}

TOOLS = ["pickaxe","bomb","drill"]               # 3 種工具
N_ACTIONS = len(TOOLS) * WIDTH * HEIGHT         # 3 × 42 = 126


# ----------------------------------------------------------
# 1. Gym 環境
# ----------------------------------------------------------
class MiningEnv(gym.Env):
    metadata = {"render.modes": ["human"]}

    def __init__(self, scroll_bonus: int = 50, max_steps: int = 200, rng_seed: int | None = None):
        super().__init__()
        self.scroll_bonus = scroll_bonus
        self.max_steps = max_steps
        self.rng = np.random.default_rng(rng_seed)

        # 機率表，總和應該 = 1.0
        self.spawn_dist = {
            "dirt":    0.3,
            "rock":    0.15,
            "e":       0.3,
            "skill":   0.05,
            "partner": 0.05,
            "copper":  0.06,
            "silver":  0.03,
            "gold":    0.01,
            "boom":    0.025,
            "drill":   0.025,
        }

        self.observation_space = spaces.Box(
            low=0, high=len(LABELS)-1,
            shape=(HEIGHT, WIDTH), dtype=np.uint8
        )
        self.action_space = spaces.Discrete(N_ACTIONS)
        self.reset()

    def _random_block(self, allow_ore: bool = False) -> str:
        """
        產生隨機新方塊（新增在最上面），
        根據 spawn_dist 中定義的機率抽樣，
        若 allow_ore=False 則先把礦石項目過濾掉再重算機率。
        """
        # 如果不允許礦石，就把它們排除並重算機率
        if not allow_ore:
            # 定義哪些 key 算是礦石
            ores = {"copper", "silver", "gold"}
            # 過濾掉 ores
            filtered = {k: v for k, v in self.spawn_dist.items() if k not in ores}
            total = sum(filtered.values())
            blocks, probs = zip(*[(k, v/total) for k, v in filtered.items()])
        else:
            # 直接使用完整分佈
            blocks, probs = zip(*self.spawn_dist.items())

        # 根據 probs 抽樣
        return self.rng.choice(blocks, p=probs)
    @staticmethod
    def _is_disconnected(lbl: str) -> bool: return lbl.startswith("dis_")
    @staticmethod
    def _strip_dis(lbl: str) -> str:       return lbl[4:] if lbl.startswith("dis_") else lbl

    def _neighbors4(self, x:int,y:int)->List[Tuple[int,int]]:
        return [(nx,ny) for nx,ny in [(x-1,y),(x+1,y),(x,y-1),(x,y+1)]
                if 0<=nx<WIDTH and 0<=ny<HEIGHT]

    def _floodfill(self):
        """更新連通區域：與 'e' 相鄰的 dis_* 變成可挖"""
        changed = True
        while changed:
            changed = False
            for y,x in itertools.product(range(HEIGHT), range(WIDTH)):
                lbl = self.board[y][x]
                if self._is_disconnected(lbl):
                    for nx,ny in self._neighbors4(x,y):
                        if self.board[ny][nx] == "e":
                            self.board[y][x] = self._strip_dis(lbl)
                            changed = True
                            break

    def _scroll_if_needed(self) -> int:
        """底行出現 'e' → 地圖下移。回傳是否加分。"""
        if any(lbl=="e" for lbl in self.board[-1]):
            # 移除最底 row，往下移，最上面加新 row
            self.board.pop()                            # 刪除 row7
            new_row = [self._random_block(allow_ore=True) for _ in range(WIDTH)]
            self.board.insert(0,new_row)                # row0
            return self.scroll_bonus
        return 0

    # ---------- Gym interface ----------------------------------------------
    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.steps = 0
        # 初始化全隨機礦場，最上層多半是 dis_
        self.board: List[List[str]] = [
            [ "dis_"+self._random_block(allow_ore=True) for _ in range(WIDTH) ]
            for _ in range(HEIGHT)
        ]
        # 先讓 (0,0) 變成已挖空，確保可連通
        self.board[0][0] = "e"
        self.board[0][2] = "e"
        self._floodfill()
        obs = self._board_to_obs()
        return obs, {}          # Gymnasium 新版需回傳 (obs, info)

    def _board_to_obs(self) -> np.ndarray:
        return np.vectorize(LBL2ID.get)(np.array(self.board, dtype=object))

    def _decode_action(self, act:int)->Tuple[str,int,int]:
        tool_id = act // (WIDTH*HEIGHT)
        rem = act % (WIDTH*HEIGHT)
        y, x = divmod(rem, WIDTH)
        return TOOLS[tool_id], x, y

    def step(self, action:int):
        self.steps += 1
        tool, x, y = self._decode_action(action)
        reward = 0
        done = False

        # ------------------ 合法性判定 ----------------------------------
        lbl = self.board[y][x]
        legal = False
        if tool == "pickaxe":
            legal = (lbl != "e") and (not self._is_disconnected(lbl))
        else:                           # bomb / drill
            legal = (lbl == "e")

        if not legal:
            reward = -100               # 大負獎
            done = True                 # 直接終結 episode
            return self._board_to_obs(), reward, done, False, {}

        # ------------------ 執行工具 ------------------------------------
        cost = 0
        score = 0

        if tool == "pickaxe":
            # 計分
            hardness = 2 if lbl == "rock" else 1
            val = {
                "copper":300,"silver":750,"gold":3000,
                "skill":1000,"partner":1000,"boom":1500,"drill":1000
            }.get(lbl,0)
            score += val
            cost += hardness
            self.board[y][x] = "e"

        elif tool == "bomb":
            # 以 (x,y) 為中心十字共 13 格
            for dx,dy in [(0,0),(1,0),(-1,0),(2,0),(-2,0),(0,1),(0,-1),(0,2),(0,-2)]:
                nx,ny = x+dx, y+dy
                if 0<=nx<WIDTH and 0<=ny<HEIGHT:
                    lbl2 = self.board[ny][nx]
                    score += {
                        "copper":300,"silver":750,"gold":3000,
                        "skill":1000,"partner":1000,"boom":1500,"drill":1000
                    }.get(lbl2,0)
                    self.board[ny][nx] = "e"
            cost += 1500                  # 這裡視需要加入炸彈「耗材」成本

        elif tool == "drill":
            # 一整欄
            for ny in range(HEIGHT):
                lbl2 = self.board[ny][x]
                score += {
                    "copper":300,"silver":750,"gold":3000,
                    "skill":1000,"partner":1000,"boom":1500,"drill":1000
                }.get(lbl2,0)
                self.board[ny][x] = "e"
            # 擊中最底再左右擴一格
            for nx in [x-1,x+1]:
                if 0<=nx<WIDTH:
                    lbl2 = self.board[HEIGHT-1][nx]
                    score += {
                        "copper":300,"silver":750,"gold":3000,
                        "skill":1000,"partner":1000,"boom":1500,"drill":1000
                    }.get(lbl2,0)
                    self.board[HEIGHT-1][nx] = "e"
            cost += 1000                  # 亦可計算鑽頭耗材

        # 更新連通性 & 滾動
        self._floodfill()
        reward = score - cost + self._scroll_if_needed()

        # episode 終止條件
        if self.steps >= self.max_steps:
            done = True

        return self._board_to_obs(), reward, done, False, {}

    def render(self, mode="human"):
        print("\n".join(" ".join(row) for row in self.board))
        print("="*30)

# ----------------------------------------------------------
# 2. 讀取老師 log  →  (s,a,r,s',done)  (可用於行為克隆)
# ----------------------------------------------------------
# def load_teacher_transitions(path: str | Path) -> List[Tuple[np.ndarray,int,float,np.ndarray,bool]]:
#     transitions = []
#     with open(path,'r',encoding='utf-8') as f:
#         for line in f:
#             if not line.strip(): continue
#             j = json.loads(line)
#             board = j["board"]
#             env = MiningEnv()
#             env.board = [row.copy() for row in board]  # deep copy
#             obs = env._board_to_obs()

#             # NOTE: 老師 logs 可能只有一個動作
#             act_info = j["actions"][0]
#             x,y = act_info["origin"]
#             tool_id = {"dig":0,"bomb":1,"drill":2}[act_info["type"]]
#             action_idx = tool_id*WIDTH*HEIGHT + y*WIDTH + x

#             # 暫時用 score - cost 當 reward
#             reward = act_info["score"] - act_info["cost"]

#             # 構造 next_state / done
#             _, _, done, _, _ = env.step(action_idx)
#             next_obs = env._board_to_obs()
#             transitions.append( (obs,action_idx,reward,next_obs,done) )
#     return transitions

# ----------------------------------------------------------
# 3. 行為克隆 (可選) ---- 需 sb3-contrib 的 `BehaviorClone`
# ----------------------------------------------------------
def load_teacher_transitions(path: str | Path) -> List[Tuple[np.ndarray,int,float,np.ndarray,bool]]:
    transitions = []
    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            j = json.loads(line)

            board = j["board"]
            env = MiningEnv()
            # 直接把老師的 board 重置進 env
            env.board = [row.copy() for row in board]
            env._floodfill()  # 確保 disconnected 狀態正確
            obs = env._board_to_obs()

            # 針對 actions list 中的每一個 action 都做一次 step
            for act_info in j.get("actions", []):
                x, y = act_info["origin"]
                tool_id = {"dig":0, "bomb":1, "drill":2}[act_info["type"]]
                action_idx = tool_id * WIDTH * HEIGHT + y * WIDTH + x

                # 直接用老師 log 裡的 score/cost 當 reward
                reward = act_info.get("score", 0) - act_info.get("cost", 0)

                # 執行這一步，取得 next_obs、done
                next_obs, _reward_from_env, done, _, _ = env.step(action_idx)
                # 注意：我們不把 env 回傳的 _reward_from_env 跟 j 裡的 reward 混在一起，
                #    這裡示範用 j 裡的 reward 作為行為克隆的 reward

                transitions.append((obs, action_idx, reward, next_obs, done))

                # 更新 obs，繼續下一個 action（如果有的話）
                obs = next_obs

    return transitions

import torch
from torch.utils.data import DataLoader, TensorDataset
from stable_baselines3.common.policies import ActorCriticPolicy

def pretrain_with_bc_custom(transitions, env, bc_epochs=50, save_path="bc_agent_custom.zip"):
    """
    自定义 BC：把 transitions flatten 成 (obs, act) dataset，用 SB3 的 Policy 当网络做 supervised learning。
    """
    # 1. flatten transitions
    obs_arr = torch.tensor([t[0] for t in transitions], dtype=torch.float32)
    act_arr = torch.tensor([t[1] for t in transitions], dtype=torch.long)
    dataset = TensorDataset(obs_arr, act_arr)
    loader  = DataLoader(dataset, batch_size=64, shuffle=True)

    # 2. 拿一个和 PPO 一模一样结构的 policy 网络
    lr_schedule = lambda _: 3e-4
    policy = ActorCriticPolicy(
        env.observation_space,
        env.action_space,
        lr_schedule,
        net_arch=[256,256],    # 与你的 PPO 一致
        normalize_images=False # 根据 env.observation_space 的需求

    )
    optimizer = torch.optim.Adam(policy.parameters(), lr=3e-4)

    # 3. 监督训练 loop
    for epoch in range(bc_epochs):
        epoch_loss = 0.0
        for b_obs, b_act in loader:
            # 得到 action distribution
            dist = policy.get_distribution(b_obs)
            log_prob = dist.log_prob(b_act)
            loss = -log_prob.mean()  # maximize log-likelihood
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        print(f"[BC] Epoch {epoch+1}/{bc_epochs}, loss {epoch_loss/len(loader):.4f}")

    # 4. 存下训练好的 policy
    # policy.save(save_path)
    # print(f"✅ 自定义 BC 模型已存：{save_path}")
    return policy


# ----------------------------------------------------------
# 4. 主程式
# ----------------------------------------------------------
def main():
    import argparse
    from pathlib import Path
    from stable_baselines3 import PPO
    from stable_baselines3.common.vec_env import DummyVecEnv

    parser = argparse.ArgumentParser()
    parser.add_argument("--teacher_file", type=str, default=r"A:\recording\emulator-5554.jsonl", help="老師 log 檔案 (json 或 jsonl)")
    parser.add_argument("--algo", choices=["PPO"], default="PPO")
    parser.add_argument("--total_timesteps", type=int, default=5000_000)
    parser.add_argument("--seed", type=int, default=42)
    args, _unknown = parser.parse_known_args()

    # 1. 建立環境（向量化）
    env_fn = lambda: MiningEnv(rng_seed=args.seed)
    vec_env = DummyVecEnv([env_fn])

    # 2. 預設為 None，如果下面進行了行為克隆會更新它
    pretrained_policy = None

    # 3. 執行行為克隆預訓練（可選）
    if args.teacher_file and Path(args.teacher_file).exists():
        print(f"📚 載入老師檔案：{args.teacher_file}")
        transitions = load_teacher_transitions(args.teacher_file)
        pretrained_policy = pretrain_with_bc_custom(transitions, vec_env, args.seed)
        print("✅ 行為克隆訓練完成")

    # 4. 初始化 PPO 模型
    if args.algo == "PPO":
        model = PPO(
            "MlpPolicy",
            vec_env,
            verbose=1,
            seed=args.seed,
            policy_kwargs=dict(net_arch=[256, 256])
        )

        # 5. 若有行為克隆權重 → 匯入 PPO 的 policy
        if pretrained_policy is not None:
            print("🧠 匯入行為克隆的權重到 PPO policy...")
            model.policy.load_state_dict(pretrained_policy.state_dict())

    else:
        raise NotImplementedError("目前只支援 PPO")

    # 6. 開始正式 PPO 訓練
    print(f"🚀 開始 PPO 訓練，共 {args.total_timesteps} 步...")
    model.learn(total_timesteps=args.total_timesteps, callback=checkpoint_callback)
    model.save("ppo_miner.zip")
    print("✅ 訓練完成，模型已存為 ppo_miner.zip")
from stable_baselines3.common.callbacks import CheckpointCallback
checkpoint_callback = CheckpointCallback(
    save_freq=10_000,                         # 幾步存一次
    save_path="./checkpoints/",              # 存檔資料夾
    name_prefix="ppo_miner"                  # 檔案前綴
)
if __name__ == "__main__":
    main()
    # env = MiningEnv(rng_seed=7)
    # # 重置并打印出当前的随机棋盘
    # env.reset()
    # env.render()
# Out:
# 📚 載入老師檔案：A:\recording\emulator-5554.jsonl
# [BC] Epoch 1/42, loss 4.7064
# [BC] Epoch 2/42, loss 4.3449
# [BC] Epoch 3/42, loss 3.8893
# [BC] Epoch 4/42, loss 3.4246
# [BC] Epoch 5/42, loss 3.0157
# [BC] Epoch 6/42, loss 2.8294
# [BC] Epoch 7/42, loss 2.5490
# [BC] Epoch 8/42, loss 2.4628
# [BC] Epoch 9/42, loss 2.4688
# [BC] Epoch 10/42, loss 2.3687
# [BC] Epoch 11/42, loss 2.2399
# [BC] Epoch 12/42, loss 2.2895
# [BC] Epoch 13/42, loss 2.1504
# [BC] Epoch 14/42, loss 2.0331
# [BC] Epoch 15/42, loss 1.9915
# [BC] Epoch 16/42, loss 2.0344
# [BC] Epoch 17/42, loss 1.7968
# [BC] Epoch 18/42, loss 1.8265
# [BC] Epoch 19/42, loss 1.7524
# [BC] Epoch 20/42, loss 1.7179
# [BC] Epoch 21/42, loss 1.7092
# [BC] Epoch 22/42, loss 1.7163
# [BC] Epoch 23/42, loss 1.6290
# [BC] Epoch 24/42, loss 1.6113
# [BC] Epoch 25/42, loss 1.5326
# [BC] Epoch 26/42, loss 1.4801
# [BC] Epoch 27/42, loss 1.3710
# [BC] Epoch 28/42, loss 1.3832
# [BC] Epoch 29/42, loss 1.2817
# [BC] Epoch 30/42, loss 1.3027
# [BC] Epoch 31/42, loss 1.2981
# [BC] Epoch 32/42, loss 1.2303
# [BC] Epoch 33/42, loss 1.1684
# [BC] Epoch 34/42, loss 1.1966
# [BC] Epoch 35/42, loss 1.1458
# [BC] Epoch 36/42, loss 1.0640
# [BC] Epoch 37/42, loss 1.0579
# [BC] Epoch 38/42, loss 1.0308
# [BC] Epoch 39/42, loss 0.9862
# [BC] Epoch 40/42, loss 0.9671
# [BC] Epoch 41/42, loss 0.9599
# [BC] Epoch 42/42, loss 0.8849
# ✅ 行為克隆訓練完成
# Using cuda device
# 🧠 匯入行為克隆的權重到 PPO policy...
# 🚀 開始 PPO 訓練，共 5000000 步...
# -----------------------------
# | time/              |      |
# |    fps             | 310  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012597311 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | -0.000275   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.14e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 2.42e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010326031 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.00958     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 1.83e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 259        |
# |    iterations           | 4          |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01624019 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.86      |
# |    explained_variance   | 0.0362     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 339        |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0187    |
# |    value_loss           | 1.3e+04    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.019759972 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.027       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00929    |
# |    value_loss           | 5.41e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 6           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.027367333 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.0356      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 1.18e+04    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 240       |
# |    iterations           | 7         |
# |    time_elapsed         | 59        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 1.2917821 |
# |    clip_fraction        | 0.725     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.51     |
# |    explained_variance   | 0.0232    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.67e+03  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | 0.0301    |
# |    value_loss           | 1.61e+04  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 8           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026577823 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.0181      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 2.17e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 243        |
# |    iterations           | 9          |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.08125069 |
# |    clip_fraction        | 0.5        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.86      |
# |    explained_variance   | 0.066      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0167     |
# |    value_loss           | 5.57e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 10          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016608557 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -0.00183    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.08e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00555     |
# |    value_loss           | 1.98e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 11          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004808559 |
# |    clip_fraction        | 0.0118      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.0289      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.7        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00324    |
# |    value_loss           | 4.76e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 12           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0005835992 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.0648       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.45e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 3.19e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 13          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.023404453 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.0427      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 1.84e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 14           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0046400903 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.0164       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 3.96e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 247           |
# |    iterations           | 15            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00023926949 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 0.0362        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.32e+04      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00287      |
# |    value_loss           | 4.91e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 248           |
# |    iterations           | 16            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00069342577 |
# |    clip_fraction        | 0.00225       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0642        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 954           |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00277      |
# |    value_loss           | 5.76e+04      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 17          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.001555058 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 2.52e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 18           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0013918352 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | 0.0703       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 404          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00803     |
# |    value_loss           | 2.78e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 19           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0016150082 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.0559       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.27e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00641     |
# |    value_loss           | 5.22e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 20           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0014830363 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.0592       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00605     |
# |    value_loss           | 2.85e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 21          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.001848411 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.0465      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 6.29e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 22           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0018592513 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.21        |
# |    explained_variance   | 0.0352       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.57e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00557     |
# |    value_loss           | 4.76e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 23           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020139483 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.0545       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 212          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00378     |
# |    value_loss           | 7e+04        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 24           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0027363205 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.0309       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+04     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0093      |
# |    value_loss           | 3.27e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 25           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0026008848 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.0592       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 4.99e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 254          |
# |    iterations           | 26           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0049971975 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.0398       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.02e+04     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00934     |
# |    value_loss           | 3.98e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 27           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0044870013 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.0288       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 502          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00573     |
# |    value_loss           | 7.1e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 28           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0049477415 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.32        |
# |    explained_variance   | 0.0405       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.95e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00795     |
# |    value_loss           | 4.78e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 29          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009050582 |
# |    clip_fraction        | 0.0703      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.0375      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 8.65e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 30          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.001521029 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.0695      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 6.26e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 31          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008486889 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.042       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.32e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 6.97e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 32           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0050514843 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.0592       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 7.22e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 33          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008122167 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.0507      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 4.86e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 34           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0021400026 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.0624       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.25e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 6.95e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 35          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007137372 |
# |    clip_fraction        | 0.00503     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.0897      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.23e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 4.34e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 36           |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0096367765 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 0.0703       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5e+03      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 6.54e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 37           |
# |    time_elapsed         | 292          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0051387073 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.64e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 4.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 38          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.002227894 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.0933      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+04    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 1.1e+05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 39           |
# |    time_elapsed         | 308          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0013160354 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.57e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 4.56e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 40          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.002044404 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 5.28e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 41          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004195384 |
# |    clip_fraction        | 0.00225     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.096       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.34e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 7.58e+04    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 259           |
# |    iterations           | 42            |
# |    time_elapsed         | 331           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00095615187 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.7          |
# |    explained_variance   | 0.123         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.08e+03      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.00127      |
# |    value_loss           | 9.79e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 43           |
# |    time_elapsed         | 339          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0029414732 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.66        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.59e+04     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 4.86e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 44           |
# |    time_elapsed         | 347          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0012488165 |
# |    clip_fraction        | 0.00747      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.61        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.86e+04     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 4.64e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 45           |
# |    time_elapsed         | 355          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0028875908 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.58e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00508     |
# |    value_loss           | 6.36e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 46           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0055270027 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.49e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 7.62e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 47           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0056952136 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.149        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.42e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 6.94e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 48           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0017078575 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.06e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 8.75e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 49           |
# |    time_elapsed         | 387          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0022225636 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.0814       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 1.68e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 50          |
# |    time_elapsed         | 395         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.006599861 |
# |    clip_fraction        | 0.00684     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.0975      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.23e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 4.45e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 51           |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0033931802 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.34e+04     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 1.39e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 52           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0059707225 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61e+04     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00721     |
# |    value_loss           | 7.32e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 53           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0034362096 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.8e+04      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 1.19e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 54           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0047328514 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.0957       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.78e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0057      |
# |    value_loss           | 7.74e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 55           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0056301123 |
# |    clip_fraction        | 0.00234      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.162        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.41e+04     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 1.29e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 56           |
# |    time_elapsed         | 443          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0035134386 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | 0.144        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8e+04      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 8.04e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 57          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.005285089 |
# |    clip_fraction        | 0.000195    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 7.33e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 58           |
# |    time_elapsed         | 458          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0018908576 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.0936       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+04     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 7.47e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 59           |
# |    time_elapsed         | 466          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0033170236 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.82e+04     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 8.3e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 60           |
# |    time_elapsed         | 473          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0019332132 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34e+04     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 1.12e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 259           |
# |    iterations           | 61            |
# |    time_elapsed         | 481           |
# |    total_timesteps      | 124928        |
# | train/                  |               |
# |    approx_kl            | 0.00088168477 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | 0.0906        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.95e+03      |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.00186      |
# |    value_loss           | 1.14e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 259           |
# |    iterations           | 62            |
# |    time_elapsed         | 488           |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# |    approx_kl            | 0.00025165148 |
# ...
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.566        |
# |    explained_variance   | 0.455         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.04e+04      |
# |    n_updates            | 4100          |
# |    policy_gradient_loss | -0.000584     |
# |    value_loss           | 1.19e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 412          |
# |    time_elapsed         | 3012         |
# |    total_timesteps      | 843776       |
# | train/                  |              |
# |    approx_kl            | 6.867753e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.94e+04     |
# |    n_updates            | 4110         |
# |    policy_gradient_loss | -0.000661    |
# |    value_loss           | 1.1e+05      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 413           |
# |    time_elapsed         | 3019          |
# |    total_timesteps      | 845824        |
# | train/                  |               |
# |    approx_kl            | 2.6782625e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.567        |
# |    explained_variance   | 0.41          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.2e+04       |
# |    n_updates            | 4120          |
# |    policy_gradient_loss | -0.000475     |
# |    value_loss           | 9.16e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 414          |
# |    time_elapsed         | 3027         |
# |    total_timesteps      | 847872       |
# | train/                  |              |
# |    approx_kl            | 5.806642e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.433        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.96e+04     |
# |    n_updates            | 4130         |
# |    policy_gradient_loss | -0.000619    |
# |    value_loss           | 1.04e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 415           |
# |    time_elapsed         | 3034          |
# |    total_timesteps      | 849920        |
# | train/                  |               |
# |    approx_kl            | 8.7208056e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.581        |
# |    explained_variance   | 0.365         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.81e+04      |
# |    n_updates            | 4140          |
# |    policy_gradient_loss | -0.000744     |
# |    value_loss           | 9.88e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 416          |
# |    time_elapsed         | 3042         |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 8.002564e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.566       |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77e+04     |
# |    n_updates            | 4150         |
# |    policy_gradient_loss | -0.000488    |
# |    value_loss           | 7.75e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 417           |
# |    time_elapsed         | 3049          |
# |    total_timesteps      | 854016        |
# | train/                  |               |
# |    approx_kl            | 3.1307834e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.588        |
# |    explained_variance   | 0.436         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.39e+04      |
# |    n_updates            | 4160          |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 1.25e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 418           |
# |    time_elapsed         | 3057          |
# |    total_timesteps      | 856064        |
# | train/                  |               |
# |    approx_kl            | 3.9832463e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.587        |
# |    explained_variance   | 0.421         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.51e+04      |
# |    n_updates            | 4170          |
# |    policy_gradient_loss | -0.000675     |
# |    value_loss           | 1.22e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 419          |
# |    time_elapsed         | 3064         |
# |    total_timesteps      | 858112       |
# | train/                  |              |
# |    approx_kl            | 0.0001315987 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+04     |
# |    n_updates            | 4180         |
# |    policy_gradient_loss | -0.000905    |
# |    value_loss           | 1.34e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 280           |
# |    iterations           | 420           |
# |    time_elapsed         | 3071          |
# |    total_timesteps      | 860160        |
# | train/                  |               |
# |    approx_kl            | 2.3553934e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.558        |
# |    explained_variance   | 0.487         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.2e+04       |
# |    n_updates            | 4190          |
# |    policy_gradient_loss | -0.000463     |
# |    value_loss           | 9.48e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 421           |
# |    time_elapsed         | 3079          |
# |    total_timesteps      | 862208        |
# | train/                  |               |
# |    approx_kl            | 8.9058565e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.6          |
# |    explained_variance   | 0.334         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.78e+04      |
# |    n_updates            | 4200          |
# |    policy_gradient_loss | -0.000631     |
# |    value_loss           | 1.7e+05       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 422          |
# |    time_elapsed         | 3086         |
# |    total_timesteps      | 864256       |
# | train/                  |              |
# |    approx_kl            | 7.197715e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.416        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+04     |
# |    n_updates            | 4210         |
# |    policy_gradient_loss | -0.000714    |
# |    value_loss           | 8.2e+04      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 423           |
# |    time_elapsed         | 3094          |
# |    total_timesteps      | 866304        |
# | train/                  |               |
# |    approx_kl            | 2.7579634e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.587        |
# |    explained_variance   | 0.503         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.09e+04      |
# |    n_updates            | 4220          |
# |    policy_gradient_loss | -0.000593     |
# |    value_loss           | 9.17e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 424           |
# |    time_elapsed         | 3101          |
# |    total_timesteps      | 868352        |
# | train/                  |               |
# |    approx_kl            | 1.7675862e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.588        |
# |    explained_variance   | 0.39          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.42e+04      |
# |    n_updates            | 4230          |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 1.27e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 425           |
# |    time_elapsed         | 3109          |
# |    total_timesteps      | 870400        |
# | train/                  |               |
# |    approx_kl            | 0.00014989602 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.533        |
# |    explained_variance   | 0.453         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.5e+04       |
# |    n_updates            | 4240          |
# |    policy_gradient_loss | -0.000638     |
# |    value_loss           | 7.38e+04      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 279           |
# |    iterations           | 426           |
# |    time_elapsed         | 3117          |
# |    total_timesteps      | 872448        |
# | train/                  |               |
# |    approx_kl            | 0.00011398754 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.564        |
# |    explained_variance   | 0.427         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5e+04         |
# |    n_updates            | 4250          |
# |    policy_gradient_loss | -0.000689     |
# |    value_loss           | 1.04e+05      |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 413
#     407 checkpoint_callback = CheckpointCallback(
#     408     save_freq=10_000,                         # 幾步存一次
#     409     save_path="./checkpoints/",              # 存檔資料夾
#     410     name_prefix="ppo_miner"                  # 檔案前綴
#     411 )
#     412 if __name__ == "__main__":
# --> 413     main()
#     414     # env = MiningEnv(rng_seed=7)
#     415     # # 重置并打印出当前的随机棋盘
#     416     # env.reset()
#     417     # env.render()
#
# Cell In[3], line 403, in main()
#     401 # 6. 開始正式 PPO 訓練
#     402 print(f"🚀 開始 PPO 訓練，共 {args.total_timesteps} 步...")
# --> 403 model.learn(total_timesteps=args.total_timesteps, callback=checkpoint_callback)
#     404 model.save("ppo_miner.zip")
#     405 print("✅ 訓練完成，模型已存為 ppo_miner.zip")
#
# File c:\Users\eric\anaconda3\envs\mushroom1\lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File c:\Users\eric\anaconda3\envs\mushroom1\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File c:\Users\eric\anaconda3\envs\mushroom1\lib\site-packages\stable_baselines3\ppo\ppo.py:207, in PPO.train(self)
#     205 approx_kl_divs = []
#     206 # Do a complete pass on the rollout buffer
# --> 207 for rollout_data in self.rollout_buffer.get(self.batch_size):
#     208     actions = rollout_data.actions
#     209     if isinstance(self.action_space, spaces.Discrete):
#     210         # Convert discrete action from float to long
#
# File c:\Users\eric\anaconda3\envs\mushroom1\lib\site-packages\stable_baselines3\common\buffers.py:505, in RolloutBuffer.get(self, batch_size)
#     503 start_idx = 0
#     504 while start_idx < self.buffer_size * self.n_envs:
# --> 505     yield self._get_samples(indices[start_idx : start_idx + batch_size])
#     506     start_idx += batch_size
#
# File c:\Users\eric\anaconda3\envs\mushroom1\lib\site-packages\stable_baselines3\common\buffers.py:521, in RolloutBuffer._get_samples(self, batch_inds, env)
#     508 def _get_samples(
#     509     self,
#     510     batch_inds: np.ndarray,
#     511     env: Optional[VecNormalize] = None,
#     512 ) -> RolloutBufferSamples:
#     513     data = (
#     514         self.observations[batch_inds],
#     515         self.actions[batch_inds],
#    (...)
#     519         self.returns[batch_inds].flatten(),
#     520     )
# --> 521     return RolloutBufferSamples(*tuple(map(self.to_torch, data)))
#
# File c:\Users\eric\anaconda3\envs\mushroom1\lib\site-packages\stable_baselines3\common\buffers.py:139, in BaseBuffer.to_torch(self, array, copy)
#     129 """
#     130 Convert a numpy array to a PyTorch tensor.
#     131 Note: it copies the data by default
#    (...)
#     136 :return:
#     137 """
#     138 if copy:
# --> 139     return th.tensor(array, device=self.device)
#     140 return th.as_tensor(array, device=self.device)
#
# KeyboardInterrupt:

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Obtaining dependency information for stable_baselines3 from https://files.pythonhosted.org/packages/54/60/6900e8186168e6e23a2125655fb4fe53130256480cc7950dadcee030cd67/stable_baselines3-2.6.0-py3-none-any.whl.metadata
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting gymnasium<1.2.0,>=0.29.1 (from stable_baselines3)
#   Obtaining dependency information for gymnasium<1.2.0,>=0.29.1 from https://files.pythonhosted.org/packages/f9/68/2bdc7b46b5f543dd865575f9d19716866bdb76e50dd33b71ed1a3dd8bb42/gymnasium-1.1.1-py3-none-any.whl.metadata
#   Downloading gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\eric\anaconda3\lib\site-packages (from stable_baselines3) (1.24.3)
# Collecting torch<3.0,>=2.3 (from stable_baselines3)
#   Obtaining dependency information for torch<3.0,>=2.3 from https://files.pythonhosted.org/packages/13/85/6c1092d4b06c3db1ed23d4106488750917156af0b24ab0a2d9951830b0e9/torch-2.7.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading torch-2.7.0-cp311-cp311-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: cloudpickle in c:\users\eric\anaconda3\lib\site-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in c:\users\eric\anaconda3\lib\site-packages (from stable_baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\eric\anaconda3\lib\site-packages (from stable_baselines3) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\eric\anaconda3\lib\site-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.2.0,>=0.29.1->stable_baselines3)
#   Obtaining dependency information for farama-notifications>=0.0.1 from https://files.pythonhosted.org/packages/05/2c/ffc08c54c05cdce6fbed2aeebc46348dbe180c6d2c541c7af7ba0aa5f5f8/Farama_Notifications-0.0.4-py3-none-any.whl.metadata
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: filelock in c:\users\eric\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.16.1)
# Collecting sympy>=1.13.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Obtaining dependency information for sympy>=1.13.3 from https://files.pythonhosted.org/packages/a2/09/77d55d46fd61b4a135c444fc97158ef34a095e5681d0a6c10b75bf356191/sympy-1.14.0-py3-none-any.whl.metadata
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\eric\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in c:\users\eric\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\eric\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable_baselines3) (2023.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\eric\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\eric\anaconda3\lib\site-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\eric\anaconda3\lib\site-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\eric\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\eric\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\eric\anaconda3\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (2.1.1)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ---------------------------------------- 0.0/184.5 kB ? eta -:--:--
#    ----------- ---------------------------- 51.2/184.5 kB 2.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 102.4/184.5 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 184.5/184.5 kB 2.2 MB/s eta 0:00:00
# Downloading gymnasium-1.1.1-py3-none-any.whl (965 kB)
#    ---------------------------------------- 0.0/965.4 kB ? eta -:--:--
#    ------- ------------------------------- 184.3/965.4 kB 10.9 MB/s eta 0:00:01
#    ------- ------------------------------- 184.3/965.4 kB 10.9 MB/s eta 0:00:01
#    --------------- ------------------------ 368.6/965.4 kB 4.6 MB/s eta 0:00:01
#    -------------------- ------------------- 501.8/965.4 kB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 665.6/965.4 kB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 849.9/965.4 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 965.4/965.4 kB 4.4 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp311-cp311-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 0
212.5 MB 5.1 MB/s eta 0:00:32
#    --------- ------------------------------ 52.8/212.5 MB 5.1 MB/s eta 0:00:32
#    --------- ------------------------------ 53.0/212.5 MB 5.1 MB/s eta 0:00:32
#    ---------- ----------------------------- 53.2/212.5 MB 5.1 MB/s eta 0:00:32
#    ---------- ----------------------------- 53.4/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 53.6/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 53.8/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 54.0/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 54.2/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 54.4/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 54.5/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 54.7/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 54.9/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 55.1/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 55.2/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 55.4/212.5 MB 5.1 MB/s eta 0:00:31
#    ---------- ----------------------------- 55.6/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 55.8/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 56.0/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 56.2/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 56.3/212.5 MB 5.1 MB/s eta 0:00:31
#    ---------- ----------------------------- 56.5/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 56.7/212.5 MB 5.1 MB/s eta 0:00:31
#    ---------- ----------------------------- 56.9/212.5 MB 5.2 MB/s eta 0:00:31
#    ---------- ----------------------------- 57.1/212.5 MB 5.2 MB/s eta 0:00:30
#    ---------- ----------------------------- 57.3/212.5 MB 5.2 MB/s eta 0:00:30
#    ---------- ----------------------------- 57.5/212.5 MB 5.2 MB/s eta 0:00:30
#    ---------- ----------------------------- 57.7/212.5 MB 5.2 MB/s eta 0:00:30
#    ---------- ----------------------------- 57.9/212.5 MB 5.2 MB/s eta 0:00:30
#    ---------- ----------------------------- 58.1/212.5 MB 5.2 MB/s eta 0:00:30
#    ---------- ----------------------------- 58.3/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 58.5/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 58.6/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 58.9/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 59.0/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 59.2/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 59.4/212.5 MB 5.3 MB/s eta 0:00:30
#    ----------- ---------------------------- 59.5/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 59.7/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 59.9/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 60.1/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 60.3/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 60.5/212.5 MB 5.2 MB/s eta 0:00:30
#    ----------- ---------------------------- 60.7/212.5 MB 5.2 MB/s eta 0:00:29
#    ----------- ---------------------------- 60.9/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 61.1/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 61.3/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 61.6/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 61.8/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 61.9/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 62.2/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 62.3/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 62.5/212.5 MB 5.3 MB/s eta 0:00:29
#    ----------- ---------------------------- 62.7/212.5 MB 5.4 MB/s eta 0:00:28
#    ----------- ---------------------------- 62.9/212.5 MB 5.4 MB/s eta 0:00:28
#    ----------- ---------------------------- 63.1/212.5 MB 5.4 MB/s eta 0:00:28
#    ----------- ---------------------------- 63.3/212.5 MB 5.4 MB/s eta 0:00:28
#    ----------- ---------------------------- 63.5/212.5 MB 5.4 MB/s eta 0:00:28
#    ----------- ---------------------------- 63.7/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 63.9/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 64.1/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 64.3/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 64.5/212.5 MB 5.5 MB/s eta 0:00:28
#    ------------ --------------------------- 64.7/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 64.8/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 65.1/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 65.2/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 65.5/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 65.7/212.5 MB 5.4 MB/s eta 0:00:28
#    ------------ --------------------------- 65.9/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 66.1/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 66.3/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 66.5/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 66.8/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 66.9/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 67.2/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 67.3/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 67.5/212.5 MB 5.6 MB/s eta 0:00:27
#    ------------ --------------------------- 67.8/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 68.0/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 68.0/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 68.2/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 68.2/212.5 MB 5.5 MB/s eta 0:00:27
#    ------------ --------------------------- 68.6/212.5 MB 5.4 MB/s eta 0:00:27
#    ------------ --------------------------- 68.7/212.5 MB 5.4 MB/s eta 0:00:27
#    ------------ --------------------------- 68.8/212.5 MB 5.4 MB/s eta 0:00:27
#    ------------ --------------------------- 69.0/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 69.1/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 69.3/212.5 MB 5.4 MB/s eta 0:00:27
#    ------------- -------------------------- 69.4/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 69.6/212.5 MB 5.3 MB/s eta 0:00:28
#    ------------- -------------------------- 69.8/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 69.9/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 70.1/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 70.3/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 70.4/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 70.6/212.5 MB 5.3 MB/s eta 0:00:27
#    ------------- -------------------------- 70.8/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 70.9/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 71.1/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 71.2/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 71.4/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 71.6/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 71.7/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 71.9/212.5 MB 5.2 MB/s eta 0:00:28
#    ------------- -------------------------- 72.1/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 72.2/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 72.5/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 72.6/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 72.8/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 72.9/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 73.2/212.5 MB 5.1 MB/s eta 0:00:28
#    ------------- -------------------------- 73.2/212.5 MB 5.0 MB/s eta 0:00:28
#    ------------- -------------------------- 73.4/212.5 MB 5.0 MB/s eta 0:00:28
#    ------------- -------------------------- 73.5/212.5 MB 5.0 MB/s eta 0:00:28
#    ------------- -------------------------- 73.8/212.5 MB 5.0 MB/s eta 0:00:28
#    ------------- -------------------------- 73.9/212.5 MB 5.0 MB/s eta 0:00:28
#    ------------- -------------------------- 74.0/212.5 MB 4.9 MB/s eta 0:00:29
#    ------------- -------------------------- 74.2/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 74.4/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 74.6/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 74.8/212.5 MB 5.0 MB/s eta 0:00:28
#    -------------- ------------------------- 75.0/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 75.2/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 75.4/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 75.5/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 75.7/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 75.9/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 76.1/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 76.3/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 76.5/212.5 MB 4.9 MB/s eta 0:00:29
#    -------------- ------------------------- 76.7/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 76.9/212.5 MB 4.8 MB/s eta 0:00:28
#    -------------- ------------------------- 77.1/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 77.3/212.5 MB 4.8 MB/s eta 0:00:29
#    -------------- ------------------------- 77.5/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 77.7/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 77.9/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 78.1/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 78.3/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 78.5/212.5 MB 5.0 MB/s eta 0:00:27
#    -------------- ------------------------- 78.7/212.5 MB 4.9 MB/s eta 0:00:28
#    -------------- ------------------------- 78.9/212.5 MB 5.0 MB/s eta 0:00:27
#    -------------- ------------------------- 79.1/212.5 MB 5.0 MB/s eta 0:00:27
#    -------------- ------------------------- 79.3/212.5 MB 5.0 MB/s eta 0:00:27
#    -------------- ------------------------- 79.5/212.5 MB 5.0 MB/s eta 0:00:27
#    --------------- ------------------------ 79.7/212.5 MB 5.1 MB/s eta 0:00:27
#    --------------- ------------------------ 79.9/212.5 MB 5.0 MB/s eta 0:00:27
#    --------------- ------------------------ 80.1/212.5 MB 5.1 MB/s eta 0:00:26
#    --------------- ------------------------ 80.3/212.5 MB 5.1 MB/s eta 0:00:26
#    --------------- ------------------------ 80.5/212.5 MB 5.2 MB/s eta 0:00:26
#    --------------- ------------------------ 80.7/212.5 MB 5.1 MB/s eta 0:00:26
#    --------------- ------------------------ 80.9/212.5 MB 5.2 MB/s eta 0:00:26
#    --------------- ------------------------ 81.0/212.5 MB 5.2 MB/s eta 0:00:26
#    --------------- ------------------------ 81.3/212.5 MB 5.2 MB/s eta 0:00:26
#    --------------- ------------------------ 81.4/212.5 MB 5.2 MB/s eta 0:00:26
#    --------------- ------------------------ 81.6/212.5 MB 5.2 MB/s eta 0:00:25
#    --------------- ------------------------ 81.8/212.5 MB 5.3 MB/s eta 0:00:25
#    --------------- ------------------------ 82.1/212.5 MB 5.2 MB/s eta 0:00:25
#    --------------- ------------------------ 82.3/212.5 MB 5.3 MB/s eta 0:00:25
#    --------------- ------------------------ 82.5/212.5 MB 5.3 MB/s eta 0:00:25
#    --------------- ------------------------ 82.7/212.5 MB 5.4 MB/s eta 0:00:25
#    --------------- ------------------------ 82.9/212.5 MB 5.4 MB/s eta 0:00:25
#    --------------- ------------------------ 83.1/212.5 MB 5.4 MB/s eta 0:00:25
#    --------------- ------------------------ 83.3/212.5 MB 5.4 MB/s eta 0:00:24
#    --------------- ------------------------ 83.5/212.5 MB 5.5 MB/s eta 0:00:24
#    --------------- ------------------------ 83.7/212.5 MB 5.5 MB/s eta 0:00:24
#    --------------- ------------------------ 84.0/212.5 MB 5.5 MB/s eta 0:00:24
#    --------------- ------------------------ 84.2/212.5 MB 5.6 MB/s eta 0:00:23
#    --------------- ------------------------ 84.4/212.5 MB 5.5 MB/s eta 0:00:24
#    --------------- ------------------------ 84.6/212.5 MB 5.6 MB/s eta 0:00:23
#    --------------- ------------------------ 84.8/212.5 MB 5.6 MB/s eta 0:00:23
#    ---------------- -----------------------