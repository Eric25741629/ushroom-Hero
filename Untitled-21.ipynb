# %%
from img_tools import click_str_by_server, check_str_in_region
import cv2
# C:\\Users\\Eric\\Downloads\\1.png
img = cv2.imread(r'C:\\Users\\Eric\\Downloads\\1.png')
result = check_str_in_region(img, "領取", y_range=(400, 582))
print(result)
# Out:
# {'combo': '暈', 'is_unwanted': False, 'normalized_combo': '暈', 'ocr_results': [{'bbox': [119, 27, 245, 57], 'bbox_rel': [0.22037037037037038, 0.14835164835164835, 0.4537037037037037, 0.3131868131868132], 'score': 0.9992452263832092, 'text': '高級熔岩寶箱'}, {'bbox': [265, 32, 390, 52], 'bbox_rel': [0.49074074074074076, 0.17582417582417584, 0.7222222222222222, 0.2857142857142857], 'score': 0.9367395043373108, 'text': '來自：夜色牡羊'}, {'bbox': [316, 74, 460, 95], 'bbox_rel': [0.5851851851851851, 0.4065934065934066, 0.8518518518518519, 0.521978021978022], 'score': 0.9959028363227844, 'text': '今日可领取数量：0/10'}, {'bbox': [356, 112, 409, 141], 'bbox_rel': [0.6592592592592592, 0.6153846153846154, 0.7574074074074074, 0.7747252747252747], 'score': 0.8877167701721191, 'text': '領取'}, {'bbox': [81, 148, 113, 171], 'bbox_rel': [0.15, 0.8131868131868132, 0.20925925925925926, 0.9395604395604396], 'score': 0.9992544651031494, 'text': 'X4'}], 'success': True}
# True
